# %% [markdown]
# # Factorial digit sum
#
# # Problem 20
# n! means n × (n − 1) × ... × 3 × 2 × 1
#
# For example, 10! = 10 × 9 × ... × 3 × 2 × 1 = 3628800,
# and the sum of the digits in the number 10! is 3 + 6 + 2 + 8 + 8 + 0 + 0 = 27.
#
# Find the sum of the digits in the number 100!

# %% [markdown]
# # Solution 20

# %%
def fac_helper(n,total):
    if n <2: return total
    else: return fac_helper(n-1,n*total)

# %%
def factorial(n): return fac_helper(n,1)

# %%
def sum_of_digits(n):
    d_s = str(n)
    s = 0
    for d in d_s: s+= int(d)
    return s

# %%
factorial(10)
# Out:
# 3628800

# %%
sum_of_digits(factorial(10))
# Out:
# 27

# %%
factorial(100)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
sum_of_digits(factorial(100))
# Out:
# 648

# %%
long = factorial(2959)

# %%
long
# Out:
# ...

# %%
len(str(long))
# Out:
# 8989

# %%
sum_of_digits(long)
# Out:
# 36720
